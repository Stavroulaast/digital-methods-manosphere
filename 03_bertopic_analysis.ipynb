# %% [markdown]
# ### BERTopic Analysis | Computer Assisted Content Analysis
#
# This notebook documents the third phase of our mixed-methods analysis, where we used Computer-Assisted Content Analysis (CACA) with BERTopic to support and refine our thematic categories. Specifically, BERTopic was applied to surface latent discourse patterns, expand our keyword sets, and validate or revise the preliminary themes identified during qualitative immersion, open coding, and axial coding.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from gensim.corpora.dictionary import Dictionary
from bertopic import BERTopic
from hdbscan import HDBSCAN
import glob

# %%
csv_files = glob.glob("money_links_df*.csv") # finding all the csv's from the scraping

# Read and concatenate all CSVs
df = pd.concat((pd.read_csv(f) for f in csv_files), ignore_index=True)

df = df[~df['text'].str.contains(r'\[deleted\]|\[\-\-removed\-\-]', case=False, na=False)].copy() # drop removed or deleted text

# %%
docs = df['text'].dropna().astype(str).tolist() # drop empty text rows

# %%
# Create custom HDBSCAN model. Min cluster size defaults to 5 but this took hours to run so I set it manually to 100. 
hdbscan_model = HDBSCAN(min_cluster_size=100, min_samples=15, metric='euclidean', prediction_data=True)

# Pass the custom clustering model into BERTopic
topic_model = BERTopic(
    language="english",
    calculate_probabilities=True,
    verbose=True,
    hdbscan_model=hdbscan_model
)


topics, probs = topic_model.fit_transform(docs)
# Out:
# 2025-05-14 11:36:26,346 - BERTopic - Embedding - Transforming documents to embeddings.
# Batches: 100%|█████████████████████████████████████████████████████████████████████| 3719/3719 [18:15<00:00,  3.40it/s]
# 2025-05-14 11:54:48,759 - BERTopic - Embedding - Completed ✓
# 2025-05-14 11:54:48,760 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2025-05-14 11:56:14,701 - BERTopic - Dimensionality - Completed ✓
# 2025-05-14 11:56:14,702 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-05-14 11:59:28,472 - BERTopic - Cluster - Completed ✓
# 2025-05-14 11:59:28,527 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-05-14 11:59:36,525 - BERTopic - Representation - Completed ✓

# %%
topic_model.get_topic_info().head(40)
# Out:
#     Topic  Count                                               Name  \
# 0      -1  64237                                  -1_to_the_and_you
# 1       0   2530                          0_alpha_beta_betas_alphas
# 2       1   2114                                1_pill_red_blue_the
# 3       2   1659                                   2_she_her_me_was
# 4       3   1621                                3_dad_my_mom_father
# 5       4   1584                         4_job_degree_business_work
# 6       5   1540                           5_life_you_your_yourself
# 7       6   1335                               6_age_old_older_year
# 8       7   1040                      7_lift_lifting_weights_weight
# 9       8    844                   8_marriage_married_divorce_marry
# 10      9    832                      9_ugly_looks_maxim_attractive
# 11     10    815            10_feminism_feminists_feminist_equality
# 12     11    786                         11_white_black_race_racist
# 13     12    774         12_prostitution_sex_prostitutes_prostitute
# 14     13    768                           13_calories_fat_eat_diet
# 15     14    765                       14_movie_movies_episode_show
# 16     15    724                              15_trp_post_this_read
# 17     16    722                                  16_he_him_she_her
# 18     17    669                        17_height_tall_short_taller
# 19     18    649                          18_rape_raped_drunk_false
# 20     19    636                        19_girls_you_approach_women
# 21     20    627                     20_porn_nofap_masturbation_fap
# 22     21    625                                21_trp_women_is_men
# 23     22    567                       22_money_funds_market_estate
# 24     23    566                        23_europe_western_are_women
# 25     24    555                        24_military_combat_army_war
# 26     25    539                           25_hair_beard_bald_shave
# 27     26    501                              26_him_he_his_husband
# 28     27    491                         27_book_books_read_reading
# 29     28    488                    28_tinder_matches_profile_girls
# 30     29    485                         29_post_thank_thanks_great
# 31     30    471                              30_city_nyc_la_cities
# 32     31    462                           31_date_drink_drinks_her
# 33     32    444                      32_asian_white_chinese_asians
# 34     33    442                                    33_10s_9s_10_8s
# 35     34    440                       34_chad_chads_thundercock_he
# 36     35    426                         35_agree_thanks_point_true
# 37     36    414  36_wrrrrroooongggg_absofuckinglutely_mortals_f...
# 38     37    397                              37_smv_high_game_your
# 39     38    390                        38_wear_dress_shoes_clothes
#
#                                        Representation  \
# 0      [to, the, and, you, of, that, is, in, it, for]
# 1   [alpha, beta, betas, alphas, is, the, an, they...
# 2   [pill, red, blue, the, of, is, and, to, that, we]
# 3   [she, her, me, was, shes, and, girl, with, to,...
# 4   [dad, my, mom, father, mother, kids, parents, ...
# 5   [job, degree, business, work, college, you, co...
# 6   [life, you, your, yourself, to, that, it, is, ...
# 7   [age, old, older, year, 30, younger, 20s, youn...
# 8   [lift, lifting, weights, weight, reps, bench, ...
# 9   [marriage, married, divorce, marry, get, contr...
# 10  [ugly, looks, maxim, attractive, game, hot, wo...
# 11  [feminism, feminists, feminist, equality, men,...
# 12  [white, black, race, racist, blacks, minority,...
# 13  [prostitution, sex, prostitutes, prostitute, h...
# 14  [calories, fat, eat, diet, weight, protein, ca...
# 15  [movie, movies, episode, show, homer, hollywoo...
# 16  [trp, post, this, read, posts, on, is, here, o...
# 17  [he, him, she, her, his, shes, was, hes, that,...
# 18  [height, tall, short, taller, shorter, guy, gu...
# 19  [rape, raped, drunk, false, consent, victims, ...
# 20  [girls, you, approach, women, your, to, with, ...
# 21  [porn, nofap, masturbation, fap, sex, fapping,...
# 22  [trp, women, is, men, about, of, that, the, th...
# 23  [money, funds, market, estate, stocks, buy, bi...
# 24  [europe, western, are, women, refugees, countr...
# 25  [military, combat, army, war, soldiers, the, i...
# 26  [hair, beard, bald, shave, grow, head, shaved,...
# 27  [him, he, his, husband, me, to, hes, we, you, ...
# 28  [book, books, read, reading, the, by, of, it, ...
# 29  [tinder, matches, profile, girls, swipe, pictu...
# 30  [post, thank, thanks, great, read, posts, writ...
# 31  [city, nyc, la, cities, in, live, york, town, ...
# 32  [date, drink, drinks, her, dates, buy, she, pa...
# 33  [asian, white, chinese, asians, asia, girls, b...
# 34  [10s, 9s, 10, 8s, 7s, girls, hot, 6s, are, looks]
# 35  [chad, chads, thundercock, he, him, his, is, a...
# 36  [agree, thanks, point, true, sense, agreed, ri...
# 37  [wrrrrroooongggg, absofuckinglutely, mortals, ...
# 38  [smv, high, game, your, low, is, value, women,...
# 39  [wear, dress, shoes, clothes, shirts, shirt, w...
#
#                                   Representative_Docs
# 0   [It’s been some time since my last post or hav...
# 1   [A beta can in certain situations choose to do...
# 2   [This, this and fucking this. It's time for th...
# 3   [Before I make this post I know I'm down bad/a...
# 4   [The haters love to argue that it was simply t...
# 5   [After seeing the recent shit storm after GLOs...
# 6   [Usually when someone seeks to change somethin...
# 7   [The same way you are meeting girls in your ag...
# 8        [Do you even lift? , Do you lift? , Lift. 1]
# 9   [Why do you want to get married? , To get out ...
# 10  [WHats your definition of an attractive guy?  ...
# 11  [I think both political extremes understand th...
# 12  [So heres the thing. Being black sucks. You're...
# 13  [I see a lot of posts on this forum about pros...
# 14  [I stopped reading after "Fats won’t make you ...
# 15  [I agree with the overall message, HOWEVER, on...
# 16  [if there is one TRP post to read so far this ...
# 17  [A story of ~4.5 years in the making I hoped t...
# 18  [Tall guys don't realise how height helps. Sho...
# 19  [You are well aware that men are held to a dif...
# 20  [Sounds like you don't enjoy shallow conversat...
# 21  [I think nofap is absolutely useless for the v...
# 22  [All fine and dandy but the reality is, most m...
# 23  [Buy a little gold or silver (I think silver i...
# 24  [To me it seems like a lot of these pickup art...
# 25  [How about instead women should not be in the ...
# 26  [I'm going to break with the mantra of "just s...
# 27  [First of all, no one went to your husband and...
# 28  [Summary: I like to read books and all books h...
# 29  [Use tinder , Make tinder. , It's been over a ...
# 30  [What a great post. Thank you so much. , Thank...
# 31  [The odds for men in NYC are great. Not trolli...
# 32  [Great FR. My only criticism is why you'd even...
# 33  [Being an Asian male is a huge disadvantage no...
# 34  [What if you're a 6, 7, or 8? Gunna keep hyopt...
# 35  [How does it feel being a chad? , Chad is an a...
# 36  [Thank you Agree , Very true. Thanks! , I comp...
# 37  [Wrrrrroooongggg -, -- Abraham Lincoln 1, Than...
# 38  [I think it's due to the social structure; whe...
# 39  [I got these about 5 months ago . They were ab...

# %%
topic_model.get_topic_info().to_csv('red_topics')
